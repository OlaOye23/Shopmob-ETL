# %% [markdown]
# These pipelines extract supermarket sales data from the Imonggo API as per https://help.imonggo.com/en/collections/154448-api, cleans the data, transforms it, and then convert it to a format more amenable for analytics. The data is then stored in an Azure Blob Storage container. The code (ex installation i.e. pip install ...) can be implemented manually as ipynb script, a local .py executable, or on Azure Functions, Azure Synapse Spark pools, or Databricks (analogous services on other cloud providers can be used as well.

# %% [markdown]
# #Code for extracting invoices from Imonggo and storing in Azure Storage as flat file
# For each page of products (50 invoices per page):
#
# 1)Retrieve the pages of data using Imonggo API as XML
#
# 2)Convert XML to JSON
#
# 3)Select columns to extract and transform
#
# 4)Flatten JSON
#
# 5)Convert JSON to CSV
#
# 6)Upload to Azure Blob Storage container

# %%
IMONGGO_UNAME = "9c59fd765e471bf004c85a218454780d29b582ac"
AZR_CONN_STR = 'DefaultEndpointsProtocol=https;AccountName=shopmobetl;AccountKey=pYhOEPZXRNUO3cxrXeCvPMaPSHuid2bWyHAnLGnCAoisRgB8Mw97eAsl4tgINm6Mh4TLqzTNyxVP+AStQdDPSg==;EndpointSuffix=core.windows.net' #os.getenv('AZURE_STORAGE_CONNECTION_STRING')

# %%
'''IMONGGO Extract Invoices into Staging Area PIPELINE'''
#install relevant packages
# !pip install xmltodict
# !pip install azure-storage-blob
#get the data
import requests
import os
#set Imonggo auth details
username = IMONGGO_UNAME#Check imonggo API support site on how to get your username
password = "x"

# Create a local directory to hold blob data
try:
  local_path = "/content/invoices"
  os.mkdir(local_path)
except Exception as e:
  print('Local path creation exception:')
  print(e)

#retrieve, flatten, and convert data
try:
  for i in range(1, 10000):
    r = requests.get(url = "https://shopmob1.imonggo.com/api/invoices.xml?after=2021-09-01%2023:59&page="+str(i), auth=(username, password) )
    #convert xml to json
    import xmltodict
    dict_data = xmltodict.parse(r.content)
    #clean the data
    if dict_data['invoices'] != None:
      try:
        data_arr = dict_data['invoices']['invoice']
        clean_data = []
        for item in data_arr:
          clean_item = {}
          item_obj = item['invoice_lines']['invoice_line']
          if not isinstance(item_obj, list):
            keys = []
            for key in item_obj.keys():
              keys.append(key)
            relevant_keys = keys[-12:]
            for key in relevant_keys:
              clean_item[key] = item_obj[key]
          else:
            for sub_item in item_obj:
              keys = []
              for key in sub_item.keys():
                keys.append(key)
              relevant_keys = keys[-12:]
              for key in relevant_keys:
                clean_item[key] = sub_item[key]
          clean_item['date'] = item['utc_invoice_date'] 
          try:
            clean_item['payment_type'] = item['payments']['payment']['payment_type_name'] 
          except Exception as e:
            print('Data cleaning error:')
            print('Failed to set payment type')
            clean_item['payment_type'] = 'unknown' 
          clean_data.append(clean_item)
        #flatten json - cleaned data
        from pandas.io.json import json_normalize
        flat_data = json_normalize(clean_data)
      except Exception as e:
        print('Data Cleaning Error: skipping...')
        print(e)
        #flatten json - no cleaning
        from pandas.io.json import json_normalize
        flat_data = json_normalize(dict_data)
      #load json to csv
      flat_data.to_csv('invoices/invoices'+str(i)+'.csv')
      print('downloaded invoices page '+ str(i))
    else:
      print('Max number of invoice pages exceeded at '+ str(i-1))
      max_page_count = i
      break
except Exception as e:
  print(e)
  


#upload the data to Azure Storage
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__

try:
    print("Starting upload process...")
    # Retrieve the connection string for use with the application. The storage
    connect_str = AZR_CONN_STR
    # Create the BlobServiceClient object which will be used to create a container client
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)

    # Create a unique name for the container
    container_name = "shopmobetlcont" #+ str(uuid.uuid4())
    try:
      container_client = blob_service_client.create_container(container_name)
    except Exception as e:
      print('Storage container creation exception:')
      print(e)
    
    #upload the files
    for i in range(1, max_page_count):
      try:
        # Create a file in the local data directory to upload and download
        local_file_name = "invoices" + str(i) + ".csv"
        upload_file_path = os.path.join(local_path, local_file_name)

        # Create a blob client using the local file name as the name for the blob
        blob_client = blob_service_client.get_blob_client(container=container_name, blob=upload_file_path)

        print("\nUploading to Azure Storage as blob:\n\t" + local_file_name)

        # Upload the created file
        with open(upload_file_path, "rb") as data:
            blob_client.upload_blob(data)
            
      except Exception as e:
        print('Upload to container exception:')
        print(e)


    # List the blobs in the container
    print("\nListing blobs...")
    blob_list = container_client.list_blobs()
    for blob in blob_list:
        print("\t" + blob.name)
        
except Exception as e:
    print('Exception: ')
    print(e)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: azure-storage-blob in /usr/local/lib/python3.7/dist-packages (12.13.1)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from azure-storage-blob) (37.0.4)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.1 in /usr/local/lib/python3.7/dist-packages (from azure-storage-blob) (1.25.0)
# Requirement already satisfied: msrest>=0.6.21 in /usr/local/lib/python3.7/dist-packages (from azure-storage-blob) (0.7.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.23.1->azure-storage-blob) (1.15.0)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.23.1->azure-storage-blob) (4.1.1)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.23.1->azure-storage-blob) (2.23.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-storage-blob) (2022.6.15)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-storage-blob) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-storage-blob) (1.3.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.1->azure-storage-blob) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.1->azure-storage-blob) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.1->azure-storage-blob) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-storage-blob) (3.2.0)
# Local path creation exception:
# [Errno 17] File exists: '/content/invoices'
# Max number of invoice pages exceeded at 450
# Starting upload process...
# Storage container creation exception:
# The specified container already exists.
# RequestId:3bc1874f-101e-0007-4f24-ba4e06000000
# Time:2022-08-27T14:51:00.3526758Z
# ErrorCode:ContainerAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>ContainerAlreadyExists</Code><Message>The specified container already exists.
# RequestId:3bc1874f-101e-0007-4f24-ba4e06000000
# Time:2022-08-27T14:51:00.3526758Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices1.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc187a7-101e-0007-1a24-ba4e06000000
# Time:2022-08-27T14:51:00.4696083Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc187a7-101e-0007-1a24-ba4e06000000
# Time:2022-08-27T14:51:00.4696083Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices2.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc187f1-101e-0007-5b24-ba4e06000000
# Time:2022-08-27T14:51:00.5505623Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc187f1-101e-0007-5b24-ba4e06000000
# Time:2022-08-27T14:51:00.5505623Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices3.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1881f-101e-0007-0124-ba4e06000000
# Time:2022-08-27T14:51:00.6355137Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1881f-101e-0007-0124-ba4e06000000
# Time:2022-08-27T14:51:00.6355137Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices4.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1886d-101e-0007-3e24-ba4e06000000
# Time:2022-08-27T14:51:00.7164684Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1886d-101e-0007-3e24-ba4e06000000
# Time:2022-08-27T14:51:00.7164684Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices5.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc188bd-101e-0007-0524-ba4e06000000
# Time:2022-08-27T14:51:00.7984206Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc188bd-101e-0007-0524-ba4e06000000
# Time:2022-08-27T14:51:00.7984206Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices6.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc188f6-101e-0007-3c24-ba4e06000000
# Time:2022-08-27T14:51:00.8803733Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc188f6-101e-0007-3c24-ba4e06000000
# Time:2022-08-27T14:51:00.8803733Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices7.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18941-101e-0007-0224-ba4e06000000
# Time:2022-08-27T14:51:00.9603276Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18941-101e-0007-0224-ba4e06000000
# Time:2022-08-27T14:51:00.9603276Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices8.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18986-101e-0007-4224-ba4e06000000
# Time:2022-08-27T14:51:01.0422806Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18986-101e-0007-4224-ba4e06000000
# Time:2022-08-27T14:51:01.0422806Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices9.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc189c6-101e-0007-7e24-ba4e06000000
# Time:2022-08-27T14:51:01.1222350Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc189c6-101e-0007-7e24-ba4e06000000
# Time:2022-08-27T14:51:01.1222350Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices10.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18a05-101e-0007-3c24-ba4e06000000
# Time:2022-08-27T14:51:01.2061869Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18a05-101e-0007-3c24-ba4e06000000
# Time:2022-08-27T14:51:01.2061869Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices11.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18a46-101e-0007-7624-ba4e06000000
# Time:2022-08-27T14:51:01.2871403Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18a46-101e-0007-7624-ba4e06000000
# Time:2022-08-27T14:51:01.2871403Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices12.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18a91-101e-0007-3424-ba4e06000000
# Time:2022-08-27T14:51:01.3670954Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18a91-101e-0007-3424-ba4e06000000
# Time:2022-08-27T14:51:01.3670954Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices13.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18ad3-101e-0007-7124-ba4e06000000
# Time:2022-08-27T14:51:01.4880266Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18ad3-101e-0007-7124-ba4e06000000
# Time:2022-08-27T14:51:01.4880266Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices14.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18b35-101e-0007-4424-ba4e06000000
# Time:2022-08-27T14:51:01.5799735Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18b35-101e-0007-4424-ba4e06000000
# Time:2022-08-27T14:51:01.5799735Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices15.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18b7e-101e-0007-0924-ba4e06000000
# Time:2022-08-27T14:51:01.6589278Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18b7e-101e-0007-0924-ba4e06000000
# Time:2022-08-27T14:51:01.6589278Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices16.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18bc7-101e-0007-4c24-ba4e06000000
# Time:2022-08-27T14:51:01.7378822Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18bc7-101e-0007-4c24-ba4e06000000
# Time:2022-08-27T14:51:01.7378822Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices17.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18c04-101e-0007-0624-ba4e06000000
# Time:2022-08-27T14:51:01.8168372Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18c04-101e-0007-0624-ba4e06000000
# Time:2022-08-27T14:51:01.8168372Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices18.csv
#
# Uploading to Azure Storage as blob:
# 	invoices19.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18c9e-101e-0007-1724-ba4e06000000
# Time:2022-08-27T14:51:02.0087267Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18c9e-101e-0007-1724-ba4e06000000
# Time:2022-08-27T14:51:02.0087267Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices20.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18cf8-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:02.0896807Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18cf8-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:02.0896807Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices21.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18d46-101e-0007-2f24-ba4e06000000
# Time:2022-08-27T14:51:02.1696351Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18d46-101e-0007-2f24-ba4e06000000
# Time:2022-08-27T14:51:02.1696351Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices22.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18d9c-101e-0007-8024-ba4e06000000
# Time:2022-08-27T14:51:02.2505886Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18d9c-101e-0007-8024-ba4e06000000
# Time:2022-08-27T14:51:02.2505886Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices23.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18de3-101e-0007-4324-ba4e06000000
# Time:2022-08-27T14:51:02.3315421Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18de3-101e-0007-4324-ba4e06000000
# Time:2022-08-27T14:51:02.3315421Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices24.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18e2d-101e-0007-0b24-ba4e06000000
# Time:2022-08-27T14:51:02.4104966Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18e2d-101e-0007-0b24-ba4e06000000
# Time:2022-08-27T14:51:02.4104966Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices25.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18e51-101e-0007-2c24-ba4e06000000
# Time:2022-08-27T14:51:02.4894522Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18e51-101e-0007-2c24-ba4e06000000
# Time:2022-08-27T14:51:02.4894522Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices26.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18e8c-101e-0007-6024-ba4e06000000
# Time:2022-08-27T14:51:02.5714046Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18e8c-101e-0007-6024-ba4e06000000
# Time:2022-08-27T14:51:02.5714046Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices27.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18ec4-101e-0007-1124-ba4e06000000
# Time:2022-08-27T14:51:02.6503592Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18ec4-101e-0007-1124-ba4e06000000
# Time:2022-08-27T14:51:02.6503592Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices28.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18f05-101e-0007-4e24-ba4e06000000
# Time:2022-08-27T14:51:02.7303136Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18f05-101e-0007-4e24-ba4e06000000
# Time:2022-08-27T14:51:02.7303136Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices29.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18f4c-101e-0007-0d24-ba4e06000000
# Time:2022-08-27T14:51:02.8212613Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18f4c-101e-0007-0d24-ba4e06000000
# Time:2022-08-27T14:51:02.8212613Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices30.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18f99-101e-0007-5724-ba4e06000000
# Time:2022-08-27T14:51:02.9012156Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18f99-101e-0007-5724-ba4e06000000
# Time:2022-08-27T14:51:02.9012156Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices31.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc18ff1-101e-0007-2524-ba4e06000000
# Time:2022-08-27T14:51:02.9801708Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc18ff1-101e-0007-2524-ba4e06000000
# Time:2022-08-27T14:51:02.9801708Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices32.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1903a-101e-0007-6924-ba4e06000000
# Time:2022-08-27T14:51:03.0721179Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1903a-101e-0007-6924-ba4e06000000
# Time:2022-08-27T14:51:03.0721179Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices33.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1906b-101e-0007-1824-ba4e06000000
# Time:2022-08-27T14:51:03.1580685Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1906b-101e-0007-1824-ba4e06000000
# Time:2022-08-27T14:51:03.1580685Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices34.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc190a9-101e-0007-5224-ba4e06000000
# Time:2022-08-27T14:51:03.2380226Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc190a9-101e-0007-5224-ba4e06000000
# Time:2022-08-27T14:51:03.2380226Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices35.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc190db-101e-0007-0124-ba4e06000000
# Time:2022-08-27T14:51:03.3189769Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc190db-101e-0007-0124-ba4e06000000
# Time:2022-08-27T14:51:03.3189769Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices36.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19121-101e-0007-4224-ba4e06000000
# Time:2022-08-27T14:51:03.4019290Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19121-101e-0007-4224-ba4e06000000
# Time:2022-08-27T14:51:03.4019290Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices37.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19151-101e-0007-7224-ba4e06000000
# Time:2022-08-27T14:51:03.4798839Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19151-101e-0007-7224-ba4e06000000
# Time:2022-08-27T14:51:03.4798839Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices38.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1917d-101e-0007-1c24-ba4e06000000
# Time:2022-08-27T14:51:03.5588400Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1917d-101e-0007-1c24-ba4e06000000
# Time:2022-08-27T14:51:03.5588400Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices39.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc191a7-101e-0007-4424-ba4e06000000
# Time:2022-08-27T14:51:03.6387932Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc191a7-101e-0007-4424-ba4e06000000
# Time:2022-08-27T14:51:03.6387932Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices40.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc191cf-101e-0007-6524-ba4e06000000
# Time:2022-08-27T14:51:03.7207457Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc191cf-101e-0007-6524-ba4e06000000
# Time:2022-08-27T14:51:03.7207457Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices41.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1920f-101e-0007-1e24-ba4e06000000
# Time:2022-08-27T14:51:03.8007005Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1920f-101e-0007-1e24-ba4e06000000
# Time:2022-08-27T14:51:03.8007005Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices42.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19249-101e-0007-5124-ba4e06000000
# Time:2022-08-27T14:51:03.8816541Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19249-101e-0007-5124-ba4e06000000
# Time:2022-08-27T14:51:03.8816541Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices43.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19286-101e-0007-0d24-ba4e06000000
# Time:2022-08-27T14:51:03.9606086Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19286-101e-0007-0d24-ba4e06000000
# Time:2022-08-27T14:51:03.9606086Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices44.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc192a4-101e-0007-2b24-ba4e06000000
# Time:2022-08-27T14:51:04.0505574Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc192a4-101e-0007-2b24-ba4e06000000
# Time:2022-08-27T14:51:04.0505574Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices45.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc192dc-101e-0007-6124-ba4e06000000
# Time:2022-08-27T14:51:04.1295116Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc192dc-101e-0007-6124-ba4e06000000
# Time:2022-08-27T14:51:04.1295116Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices46.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19314-101e-0007-1624-ba4e06000000
# Time:2022-08-27T14:51:04.2074670Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19314-101e-0007-1624-ba4e06000000
# Time:2022-08-27T14:51:04.2074670Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices47.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19353-101e-0007-4f24-ba4e06000000
# Time:2022-08-27T14:51:04.2874220Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19353-101e-0007-4f24-ba4e06000000
# Time:2022-08-27T14:51:04.2874220Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices48.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1938b-101e-0007-7f24-ba4e06000000
# Time:2022-08-27T14:51:04.3703740Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1938b-101e-0007-7f24-ba4e06000000
# Time:2022-08-27T14:51:04.3703740Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices49.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc193ca-101e-0007-3724-ba4e06000000
# Time:2022-08-27T14:51:04.4483292Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc193ca-101e-0007-3724-ba4e06000000
# Time:2022-08-27T14:51:04.4483292Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices50.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19404-101e-0007-6e24-ba4e06000000
# Time:2022-08-27T14:51:04.5282841Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19404-101e-0007-6e24-ba4e06000000
# Time:2022-08-27T14:51:04.5282841Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices51.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1943b-101e-0007-2124-ba4e06000000
# Time:2022-08-27T14:51:04.6072388Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1943b-101e-0007-2124-ba4e06000000
# Time:2022-08-27T14:51:04.6072388Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices52.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19470-101e-0007-5224-ba4e06000000
# Time:2022-08-27T14:51:04.6901923Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19470-101e-0007-5224-ba4e06000000
# Time:2022-08-27T14:51:04.6901923Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices53.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc194a6-101e-0007-0524-ba4e06000000
# Time:2022-08-27T14:51:04.7701450Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc194a6-101e-0007-0524-ba4e06000000
# Time:2022-08-27T14:51:04.7701450Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices54.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc194d5-101e-0007-2f24-ba4e06000000
# Time:2022-08-27T14:51:04.8471010Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc194d5-101e-0007-2f24-ba4e06000000
# Time:2022-08-27T14:51:04.8471010Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices55.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19511-101e-0007-6224-ba4e06000000
# Time:2022-08-27T14:51:04.9250578Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19511-101e-0007-6224-ba4e06000000
# Time:2022-08-27T14:51:04.9250578Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices56.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19547-101e-0007-1324-ba4e06000000
# Time:2022-08-27T14:51:05.0020131Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19547-101e-0007-1324-ba4e06000000
# Time:2022-08-27T14:51:05.0020131Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices57.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1957f-101e-0007-4924-ba4e06000000
# Time:2022-08-27T14:51:05.0839656Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1957f-101e-0007-4924-ba4e06000000
# Time:2022-08-27T14:51:05.0839656Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices58.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc195b3-101e-0007-7c24-ba4e06000000
# Time:2022-08-27T14:51:05.1649194Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc195b3-101e-0007-7c24-ba4e06000000
# Time:2022-08-27T14:51:05.1649194Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices59.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc195f6-101e-0007-3424-ba4e06000000
# Time:2022-08-27T14:51:05.2458736Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc195f6-101e-0007-3424-ba4e06000000
# Time:2022-08-27T14:51:05.2458736Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices60.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19629-101e-0007-6124-ba4e06000000
# Time:2022-08-27T14:51:05.3248269Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19629-101e-0007-6124-ba4e06000000
# Time:2022-08-27T14:51:05.3248269Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices61.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1966e-101e-0007-2324-ba4e06000000
# Time:2022-08-27T14:51:05.4067802Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1966e-101e-0007-2324-ba4e06000000
# Time:2022-08-27T14:51:05.4067802Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices62.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc196b6-101e-0007-6524-ba4e06000000
# Time:2022-08-27T14:51:05.4847357Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc196b6-101e-0007-6524-ba4e06000000
# Time:2022-08-27T14:51:05.4847357Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices63.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc196f4-101e-0007-2024-ba4e06000000
# Time:2022-08-27T14:51:05.5636910Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc196f4-101e-0007-2024-ba4e06000000
# Time:2022-08-27T14:51:05.5636910Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices64.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19731-101e-0007-5524-ba4e06000000
# Time:2022-08-27T14:51:05.6436449Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19731-101e-0007-5524-ba4e06000000
# Time:2022-08-27T14:51:05.6436449Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices65.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19763-101e-0007-0224-ba4e06000000
# Time:2022-08-27T14:51:05.7225996Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19763-101e-0007-0224-ba4e06000000
# Time:2022-08-27T14:51:05.7225996Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices66.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc197a3-101e-0007-3d24-ba4e06000000
# Time:2022-08-27T14:51:05.8005550Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc197a3-101e-0007-3d24-ba4e06000000
# Time:2022-08-27T14:51:05.8005550Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices67.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc197dd-101e-0007-7524-ba4e06000000
# Time:2022-08-27T14:51:05.8815099Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc197dd-101e-0007-7524-ba4e06000000
# Time:2022-08-27T14:51:05.8815099Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices68.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19831-101e-0007-4224-ba4e06000000
# Time:2022-08-27T14:51:05.9604626Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19831-101e-0007-4224-ba4e06000000
# Time:2022-08-27T14:51:05.9604626Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices69.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19869-101e-0007-6f24-ba4e06000000
# Time:2022-08-27T14:51:06.0414171Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19869-101e-0007-6f24-ba4e06000000
# Time:2022-08-27T14:51:06.0414171Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices70.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc198b6-101e-0007-2f24-ba4e06000000
# Time:2022-08-27T14:51:06.1293672Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc198b6-101e-0007-2f24-ba4e06000000
# Time:2022-08-27T14:51:06.1293672Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices71.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc198f3-101e-0007-6824-ba4e06000000
# Time:2022-08-27T14:51:06.2083210Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc198f3-101e-0007-6824-ba4e06000000
# Time:2022-08-27T14:51:06.2083210Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices72.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19925-101e-0007-1624-ba4e06000000
# Time:2022-08-27T14:51:06.2872755Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19925-101e-0007-1624-ba4e06000000
# Time:2022-08-27T14:51:06.2872755Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices73.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19955-101e-0007-4424-ba4e06000000
# Time:2022-08-27T14:51:06.3652314Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19955-101e-0007-4424-ba4e06000000
# Time:2022-08-27T14:51:06.3652314Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices74.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1998f-101e-0007-7c24-ba4e06000000
# Time:2022-08-27T14:51:06.4431870Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1998f-101e-0007-7c24-ba4e06000000
# Time:2022-08-27T14:51:06.4431870Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices75.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc199d1-101e-0007-3924-ba4e06000000
# Time:2022-08-27T14:51:06.5231412Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc199d1-101e-0007-3924-ba4e06000000
# Time:2022-08-27T14:51:06.5231412Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices76.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19a07-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:06.6020959Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19a07-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:06.6020959Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices77.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19a34-101e-0007-1524-ba4e06000000
# Time:2022-08-27T14:51:06.6810507Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19a34-101e-0007-1524-ba4e06000000
# Time:2022-08-27T14:51:06.6810507Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices78.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19a69-101e-0007-4824-ba4e06000000
# Time:2022-08-27T14:51:06.7590063Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19a69-101e-0007-4824-ba4e06000000
# Time:2022-08-27T14:51:06.7590063Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices79.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19aaa-101e-0007-0124-ba4e06000000
# Time:2022-08-27T14:51:06.8429574Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19aaa-101e-0007-0124-ba4e06000000
# Time:2022-08-27T14:51:06.8429574Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices80.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19ad9-101e-0007-2f24-ba4e06000000
# Time:2022-08-27T14:51:06.9259102Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19ad9-101e-0007-2f24-ba4e06000000
# Time:2022-08-27T14:51:06.9259102Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices81.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19b1f-101e-0007-6d24-ba4e06000000
# Time:2022-08-27T14:51:07.0048647Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19b1f-101e-0007-6d24-ba4e06000000
# Time:2022-08-27T14:51:07.0048647Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices82.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19b4d-101e-0007-1824-ba4e06000000
# Time:2022-08-27T14:51:07.0928148Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19b4d-101e-0007-1824-ba4e06000000
# Time:2022-08-27T14:51:07.0928148Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices83.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19b8e-101e-0007-5424-ba4e06000000
# Time:2022-08-27T14:51:07.1727684Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19b8e-101e-0007-5424-ba4e06000000
# Time:2022-08-27T14:51:07.1727684Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices84.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19bbf-101e-0007-0524-ba4e06000000
# Time:2022-08-27T14:51:07.2527225Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19bbf-101e-0007-0524-ba4e06000000
# Time:2022-08-27T14:51:07.2527225Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices85.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19bef-101e-0007-3324-ba4e06000000
# Time:2022-08-27T14:51:07.3346758Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19bef-101e-0007-3324-ba4e06000000
# Time:2022-08-27T14:51:07.3346758Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices86.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19c1a-101e-0007-5e24-ba4e06000000
# Time:2022-08-27T14:51:07.4136310Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19c1a-101e-0007-5e24-ba4e06000000
# Time:2022-08-27T14:51:07.4136310Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices87.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19c41-101e-0007-0124-ba4e06000000
# Time:2022-08-27T14:51:07.4945841Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19c41-101e-0007-0124-ba4e06000000
# Time:2022-08-27T14:51:07.4945841Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices88.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19c7d-101e-0007-3724-ba4e06000000
# Time:2022-08-27T14:51:07.5745381Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19c7d-101e-0007-3724-ba4e06000000
# Time:2022-08-27T14:51:07.5745381Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices89.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19cb0-101e-0007-6724-ba4e06000000
# Time:2022-08-27T14:51:07.6554918Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19cb0-101e-0007-6724-ba4e06000000
# Time:2022-08-27T14:51:07.6554918Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices90.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19cda-101e-0007-0b24-ba4e06000000
# Time:2022-08-27T14:51:07.7354462Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19cda-101e-0007-0b24-ba4e06000000
# Time:2022-08-27T14:51:07.7354462Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices91.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19d06-101e-0007-3124-ba4e06000000
# Time:2022-08-27T14:51:07.8154003Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19d06-101e-0007-3124-ba4e06000000
# Time:2022-08-27T14:51:07.8154003Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices92.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19d4f-101e-0007-7824-ba4e06000000
# Time:2022-08-27T14:51:07.8973534Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19d4f-101e-0007-7824-ba4e06000000
# Time:2022-08-27T14:51:07.8973534Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices93.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19d99-101e-0007-4024-ba4e06000000
# Time:2022-08-27T14:51:07.9753094Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19d99-101e-0007-4024-ba4e06000000
# Time:2022-08-27T14:51:07.9753094Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices94.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19dbc-101e-0007-6224-ba4e06000000
# Time:2022-08-27T14:51:08.0602620Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19dbc-101e-0007-6224-ba4e06000000
# Time:2022-08-27T14:51:08.0602620Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices95.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19df5-101e-0007-1624-ba4e06000000
# Time:2022-08-27T14:51:08.1382155Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19df5-101e-0007-1624-ba4e06000000
# Time:2022-08-27T14:51:08.1382155Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices96.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19e35-101e-0007-5024-ba4e06000000
# Time:2022-08-27T14:51:08.2211684Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19e35-101e-0007-5024-ba4e06000000
# Time:2022-08-27T14:51:08.2211684Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices97.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19e68-101e-0007-7f24-ba4e06000000
# Time:2022-08-27T14:51:08.3011229Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19e68-101e-0007-7f24-ba4e06000000
# Time:2022-08-27T14:51:08.3011229Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices98.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19ea9-101e-0007-3824-ba4e06000000
# Time:2022-08-27T14:51:08.3840749Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19ea9-101e-0007-3824-ba4e06000000
# Time:2022-08-27T14:51:08.3840749Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices99.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc19ede-101e-0007-6424-ba4e06000000
# Time:2022-08-27T14:51:08.4630303Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc19ede-101e-0007-6424-ba4e06000000
# Time:2022-08-27T14:51:08.4630303Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices100.csv
# Upload to container exception:
# The specified blob already exists.
# ...
# 	invoices415.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1eb9f-101e-0007-1e24-ba4e06000000
# Time:2022-08-27T14:51:34.4911454Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1eb9f-101e-0007-1e24-ba4e06000000
# Time:2022-08-27T14:51:34.4911454Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices416.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ebd5-101e-0007-5224-ba4e06000000
# Time:2022-08-27T14:51:34.5720998Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ebd5-101e-0007-5224-ba4e06000000
# Time:2022-08-27T14:51:34.5720998Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices417.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ec0f-101e-0007-0524-ba4e06000000
# Time:2022-08-27T14:51:34.6600495Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ec0f-101e-0007-0524-ba4e06000000
# Time:2022-08-27T14:51:34.6600495Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices418.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ec41-101e-0007-3424-ba4e06000000
# Time:2022-08-27T14:51:34.7400040Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ec41-101e-0007-3424-ba4e06000000
# Time:2022-08-27T14:51:34.7400040Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices419.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ec6e-101e-0007-5f24-ba4e06000000
# Time:2022-08-27T14:51:34.8179593Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ec6e-101e-0007-5f24-ba4e06000000
# Time:2022-08-27T14:51:34.8179593Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices420.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ec92-101e-0007-7e24-ba4e06000000
# Time:2022-08-27T14:51:34.8959150Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ec92-101e-0007-7e24-ba4e06000000
# Time:2022-08-27T14:51:34.8959150Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices421.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ecd0-101e-0007-3824-ba4e06000000
# Time:2022-08-27T14:51:34.9748695Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ecd0-101e-0007-3824-ba4e06000000
# Time:2022-08-27T14:51:34.9748695Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices422.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ed03-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:35.0538233Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ed03-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:35.0538233Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices423.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ed3f-101e-0007-2124-ba4e06000000
# Time:2022-08-27T14:51:35.1337781Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ed3f-101e-0007-2124-ba4e06000000
# Time:2022-08-27T14:51:35.1337781Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices424.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ed79-101e-0007-5624-ba4e06000000
# Time:2022-08-27T14:51:35.2127343Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ed79-101e-0007-5624-ba4e06000000
# Time:2022-08-27T14:51:35.2127343Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices425.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1edad-101e-0007-8024-ba4e06000000
# Time:2022-08-27T14:51:35.2916876Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1edad-101e-0007-8024-ba4e06000000
# Time:2022-08-27T14:51:35.2916876Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices426.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1eddd-101e-0007-2d24-ba4e06000000
# Time:2022-08-27T14:51:35.3706432Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1eddd-101e-0007-2d24-ba4e06000000
# Time:2022-08-27T14:51:35.3706432Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices427.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ee1b-101e-0007-6924-ba4e06000000
# Time:2022-08-27T14:51:35.4495972Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ee1b-101e-0007-6924-ba4e06000000
# Time:2022-08-27T14:51:35.4495972Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices428.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ee3b-101e-0007-0724-ba4e06000000
# Time:2022-08-27T14:51:35.5295516Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ee3b-101e-0007-0724-ba4e06000000
# Time:2022-08-27T14:51:35.5295516Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices429.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ee76-101e-0007-3c24-ba4e06000000
# Time:2022-08-27T14:51:35.6075077Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ee76-101e-0007-3c24-ba4e06000000
# Time:2022-08-27T14:51:35.6075077Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices430.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1eea1-101e-0007-6524-ba4e06000000
# Time:2022-08-27T14:51:35.6864618Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1eea1-101e-0007-6524-ba4e06000000
# Time:2022-08-27T14:51:35.6864618Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices431.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1eed9-101e-0007-1924-ba4e06000000
# Time:2022-08-27T14:51:35.7664162Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1eed9-101e-0007-1924-ba4e06000000
# Time:2022-08-27T14:51:35.7664162Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices432.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ef0a-101e-0007-4724-ba4e06000000
# Time:2022-08-27T14:51:35.8463709Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ef0a-101e-0007-4724-ba4e06000000
# Time:2022-08-27T14:51:35.8463709Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices433.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ef41-101e-0007-7c24-ba4e06000000
# Time:2022-08-27T14:51:35.9253261Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ef41-101e-0007-7c24-ba4e06000000
# Time:2022-08-27T14:51:35.9253261Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices434.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1ef86-101e-0007-3d24-ba4e06000000
# Time:2022-08-27T14:51:36.0072787Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1ef86-101e-0007-3d24-ba4e06000000
# Time:2022-08-27T14:51:36.0072787Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices435.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1efd9-101e-0007-0b24-ba4e06000000
# Time:2022-08-27T14:51:36.0962277Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1efd9-101e-0007-0b24-ba4e06000000
# Time:2022-08-27T14:51:36.0962277Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices436.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f00d-101e-0007-3a24-ba4e06000000
# Time:2022-08-27T14:51:36.1781831Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f00d-101e-0007-3a24-ba4e06000000
# Time:2022-08-27T14:51:36.1781831Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices437.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f053-101e-0007-7624-ba4e06000000
# Time:2022-08-27T14:51:36.2601341Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f053-101e-0007-7624-ba4e06000000
# Time:2022-08-27T14:51:36.2601341Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices438.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f091-101e-0007-3024-ba4e06000000
# Time:2022-08-27T14:51:36.3390898Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f091-101e-0007-3024-ba4e06000000
# Time:2022-08-27T14:51:36.3390898Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices439.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f0ce-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:36.4180442Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f0ce-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:36.4180442Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices440.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f10f-101e-0007-2724-ba4e06000000
# Time:2022-08-27T14:51:36.4960001Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f10f-101e-0007-2724-ba4e06000000
# Time:2022-08-27T14:51:36.4960001Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices441.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f153-101e-0007-6224-ba4e06000000
# Time:2022-08-27T14:51:36.5769532Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f153-101e-0007-6224-ba4e06000000
# Time:2022-08-27T14:51:36.5769532Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices442.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f187-101e-0007-0d24-ba4e06000000
# Time:2022-08-27T14:51:36.6549083Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f187-101e-0007-0d24-ba4e06000000
# Time:2022-08-27T14:51:36.6549083Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices443.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f1c7-101e-0007-4424-ba4e06000000
# Time:2022-08-27T14:51:36.7358626Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f1c7-101e-0007-4424-ba4e06000000
# Time:2022-08-27T14:51:36.7358626Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices444.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f201-101e-0007-7824-ba4e06000000
# Time:2022-08-27T14:51:36.8148171Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f201-101e-0007-7824-ba4e06000000
# Time:2022-08-27T14:51:36.8148171Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices445.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f225-101e-0007-1524-ba4e06000000
# Time:2022-08-27T14:51:36.8957713Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f225-101e-0007-1524-ba4e06000000
# Time:2022-08-27T14:51:36.8957713Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices446.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f251-101e-0007-3c24-ba4e06000000
# Time:2022-08-27T14:51:36.9807225Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f251-101e-0007-3c24-ba4e06000000
# Time:2022-08-27T14:51:36.9807225Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices447.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f282-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:37.0656740Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f282-101e-0007-6b24-ba4e06000000
# Time:2022-08-27T14:51:37.0656740Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices448.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f2b6-101e-0007-1d24-ba4e06000000
# Time:2022-08-27T14:51:37.1496259Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f2b6-101e-0007-1d24-ba4e06000000
# Time:2022-08-27T14:51:37.1496259Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	invoices449.csv
# Upload to container exception:
# The specified blob already exists.
# RequestId:3bc1f2e2-101e-0007-4824-ba4e06000000
# Time:2022-08-27T14:51:37.2305799Z
# ErrorCode:BlobAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>BlobAlreadyExists</Code><Message>The specified blob already exists.
# RequestId:3bc1f2e2-101e-0007-4824-ba4e06000000
# Time:2022-08-27T14:51:37.2305799Z</Message></Error>
#
# Listing blobs...
# Exception:
# name 'container_client' is not defined

# %% [markdown]
# #Code for extracting products from Imonggo and storing in Azure Storage as flat file
# For each page of products (50 products per page):
#
#
# 1)Retrieve the pages of data using Imonggo API as XML
#
# 2)Convert XML to JSON
#
# 3)Select columns to extract and transform
#
# 4)Flatten JSON
#
# 5)Convert JSON to CSV
#
# 6)Upload to Azure Blob Storage container

# %%
'''IMONGGO Extract Products into Staging Area PIPELINE'''
#install relevant packages
# !pip install xmltodict
# !pip install azure-storage-blob
#get the data
import requests
import os
#set Imonggo auth details
username = "9c59fd765e471bf004c85a218454780d29b582ac"#Check imonggo API support site on how to get your username
password = "x"

# Create a local directory to hold blob data
try:
  local_path = "/content/products"
  os.mkdir(local_path)
except Exception as e:
  print('Local path creation exception:')
  print(e)

#retrieve, flatten, and convert data
try:
  for i in range(1, 10000):
    r = requests.get(url = "https://shopmob1.imonggo.com/api/products.xml?active_only=1&page="+ str(i), auth=(username, password) )
    #convert xml to json
    import xmltodict
    dict_data = xmltodict.parse(r.content)
    #flatten json
    if dict_data['products'] != None:
      try:
        data_arr = dict_data['products']['product']
        keys = []
        for key in data_arr[0]['inventories']['inventory'].keys():
          keys.append(key)
        #print(keys[:])
        clean_data = []
        for item in data_arr:
          clean_item = {}
          item_obj = item['inventories']['inventory']
          keys = []
          for key in item_obj.keys():
            keys.append(key)
          relevant_keys = keys[:]
          for key in relevant_keys:
            clean_item[key] = item_obj[key]
          clean_data.append(clean_item)
          from pandas.io.json import json_normalize
          flat_data = json_normalize(clean_data)
      except Exception as e:
        print('Data Cleaning Error: skipping...')
        print(e)
        #flatten json - no cleaning
        from pandas.io.json import json_normalize
        flat_data = json_normalize(dict_data)
      #load json to csv
      flat_data.to_csv('products/products'+str(i)+'.csv')
      print('downloaded products page '+ str(i))
    else:
      print('Max number of product pages exceeded at '+ str(i-1))
      max_page_count = i
      break
except Exception as e:
  print(e)


#upload the data to Azure Storage
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient, __version__

try:
    print("Starting upload process...")
    # Retrieve the connection string for use with the application. The storage
    connect_str = 'DefaultEndpointsProtocol=https;AccountName=shopmobetl;AccountKey=pYhOEPZXRNUO3cxrXeCvPMaPSHuid2bWyHAnLGnCAoisRgB8Mw97eAsl4tgINm6Mh4TLqzTNyxVP+AStQdDPSg==;EndpointSuffix=core.windows.net' #os.getenv('AZURE_STORAGE_CONNECTION_STRING')
    # Create the BlobServiceClient object which will be used to create a container client
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)

    # Create a unique name for the container
    container_name = "shopmobetlcont" #+ str(uuid.uuid4())
    try:
      container_client = blob_service_client.create_container(container_name)
    except Exception as e:
      print('Storage container creation exception:')
      print(e)
    
    #upload the files
    for i in range(1, max_page_count):
      try:
        # Create a file in the local data directory to upload and download
        local_file_name = "products" + str(i) + ".csv"
        upload_file_path = os.path.join(local_path, local_file_name)

        # Create a blob client using the local file name as the name for the blob
        blob_client = blob_service_client.get_blob_client(container=container_name, blob=upload_file_path)

        print("\nUploading to Azure Storage as blob:\n\t" + local_file_name)

        # Upload the created file
        with open(upload_file_path, "rb") as data:
            blob_client.upload_blob(data)
            
      except Exception as e:
        print('Upload to container exception:')
        print(e)


    # List the blobs in the container
    print("\nListing blobs...")
    blob_list = container_client.list_blobs()
    for blob in blob_list:
        print("\t" + blob.name)
        
except Exception as e:
    print('Exception: ')
    print(e)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: azure-storage-blob in /usr/local/lib/python3.7/dist-packages (12.13.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.1 in /usr/local/lib/python3.7/dist-packages (from azure-storage-blob) (1.25.1)
# Requirement already satisfied: msrest>=0.6.21 in /usr/local/lib/python3.7/dist-packages (from azure-storage-blob) (0.7.1)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from azure-storage-blob) (37.0.4)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.23.1->azure-storage-blob) (4.1.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.23.1->azure-storage-blob) (1.15.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from azure-core<2.0.0,>=1.23.1->azure-storage-blob) (2.23.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.21)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-storage-blob) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-storage-blob) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from msrest>=0.6.21->azure-storage-blob) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.1->azure-storage-blob) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.1->azure-storage-blob) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.1->azure-storage-blob) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-storage-blob) (3.2.0)
# Local path creation exception:
# [Errno 17] File exists: '/content/products'
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:47: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# downloaded products page 1
# downloaded products page 2
# Data Cleaning Error: skipping...
# 'inventory'
# downloaded products page 3
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:53: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# downloaded products page 4
# downloaded products page 5
# downloaded products page 6
# downloaded products page 7
# downloaded products page 8
# Data Cleaning Error: skipping...
# 'inventory'
# downloaded products page 9
# Max number of product pages exceeded at 9
# Starting upload process...
# Storage container creation exception:
# The specified container already exists.
# RequestId:a8ce58e9-301e-002f-1457-be2fae000000
# Time:2022-09-01T23:03:27.6506949Z
# ErrorCode:ContainerAlreadyExists
# Content: <?xml version="1.0" encoding="utf-8"?><Error><Code>ContainerAlreadyExists</Code><Message>The specified container already exists.
# RequestId:a8ce58e9-301e-002f-1457-be2fae000000
# Time:2022-09-01T23:03:27.6506949Z</Message></Error>
#
# Uploading to Azure Storage as blob:
# 	products1.csv
#
# Uploading to Azure Storage as blob:
# 	products2.csv
#
# Uploading to Azure Storage as blob:
# 	products3.csv
#
# Uploading to Azure Storage as blob:
# 	products4.csv
#
# Uploading to Azure Storage as blob:
# 	products5.csv
#
# Uploading to Azure Storage as blob:
# 	products6.csv
#
# Uploading to Azure Storage as blob:
# 	products7.csv
#
# Uploading to Azure Storage as blob:
# 	products8.csv
#
# Uploading to Azure Storage as blob:
# 	products9.csv
#
# Listing blobs...
# Exception:
# name 'container_client' is not defined

# %%
# Out:
# 1
